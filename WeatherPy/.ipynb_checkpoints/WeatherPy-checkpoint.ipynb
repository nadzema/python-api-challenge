# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy import stats
from scipy.stats import linregress
import pprint as pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
base = "http://api.openweathermap.org/data/2.5/weather?" 
units = "metric"

# Build partial query URL

url = f'{base}appid={weather_api_key}&units={units}&q='
response = requests.get(url + city)
weather = response.json()
print(json.dumps(weather, indent =4))
# Out:
# {
#     "cod": 429,
#     "message": "Your account is temporary blocked due to exceeding of requests limitation of your subscription type. Please choose the proper subscription http://openweathermap.org/price"
# }

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a City dataframe
citydf = pd.DataFrame({'City': cities})
citydf
# Out:
#               City
# 0         tumannyy
# 1        jamestown
# 2            arica
# 3         thompson
# 4            kapaa
# ..             ...
# 624         batken
# 625  san cristobal
# 626           payo
# 627       naumburg
# 628         miyako
#
# [629 rows x 1 columns]

# %%
#citydf["Country"] = ""
#citydf["Latitude"] = ""
#citydf["Longitude"] = ""
#citydf["Temperature (F)"] = ""
#citydf["Humidity"] = ""
#citydf["Cloudiness"] = ""
#citydf["Wind Speed (mph)"] = ""
place =[]
country = []
latitude = []
longitude = []
temperature = []
humidity = []
cloudiness=[]
wind_speed= []
city_data = []

# %%
# Save config information.
base = "http://api.openweathermap.org/data/2.5/weather?" 
units = "metric"


city_data = []

for city in cities:
    url = f'{base}appid={weather_api_key}&units={units}&q='
    print(f" Found this {city}")
    try:
        response = requests.get(url + city).json()
        country = response["sys"]["country"]
        latitude= response["coord"]["lat"]
        longitude =response["coord"]["lon"]
        temperature = response["main"]["temp"]
        humidity =response["main"]["humidity"]
        cloudiness= response["clouds"]["all"]
        wind_speed=response["wind"]["speed"]
        city_data.append({"City":city, "Country": country, 'Latitude':latitude, 
                          "Longitude": longitude, "Temperature": temperature, "Humidity": humidity,
                         "Cloudiness": cloudiness, "Windspeed": wind_speed})

    except:
        print("Country not found")
# Out:
#  Found this tumannyy
# Country not found
#  Found this jamestown
# Country not found
#  Found this arica
# Country not found
#  Found this thompson
# Country not found
#  Found this kapaa
# Country not found
#  Found this banda aceh
# Country not found
#  Found this busselton
# Country not found
#  Found this saint george
# Country not found
#  Found this guerrero negro
# Country not found
#  Found this atherton
# Country not found
#  Found this rikitea
# Country not found
#  Found this ushuaia
# Country not found
#  Found this pleasanton
# Country not found
#  Found this tabiauea
# Country not found
#  Found this tasiilaq
# Country not found
#  Found this avarua
# Country not found
#  Found this tautira
# Country not found
#  Found this roura
# Country not found
#  Found this albany
# Country not found
#  Found this hilo
# Country not found
#  Found this barrow
# Country not found
#  Found this hithadhoo
# Country not found
#  Found this chapais
# Country not found
#  Found this bredasdorp
# Country not found
#  Found this aflu
# Country not found
#  Found this atuona
# Country not found
#  Found this nanortalik
# Country not found
#  Found this pisco
# Country not found
#  Found this kaitangata
# Country not found
#  Found this aquiles serdan
# Country not found
#  Found this carlisle
# Country not found
#  Found this avera
# Country not found
#  Found this harper
# Country not found
#  Found this lebu
# Country not found
#  Found this yellowknife
# Country not found
#  Found this halalo
# Country not found
#  Found this sitka
# Country not found
#  Found this viligili
# Country not found
#  Found this ust-kuyga
# Country not found
#  Found this labuan
# Country not found
#  Found this khatanga
# Country not found
#  Found this amderma
# Country not found
#  Found this hervey bay
# Country not found
#  Found this bom jesus do galho
# Country not found
#  Found this sao sebastiao
# Country not found
#  Found this bluff
# Country not found
#  Found this mar del plata
# Country not found
#  Found this cockburn town
# Country not found
#  Found this hobart
# Country not found
#  Found this sao filipe
# Country not found
#  Found this punta arenas
# Country not found
#  Found this cartagena
# Country not found
#  Found this wattegama
# Country not found
#  Found this ribeira grande
# Country not found
#  Found this margate
# Country not found
#  Found this port alfred
# Country not found
#  Found this torbay
# Country not found
#  Found this aasiaat
# Country not found
#  Found this vila franca do campo
# Country not found
#  Found this saint-philippe
# Country not found
#  Found this illoqqortoormiut
# Country not found
#  Found this gisors
# Country not found
#  Found this hermanus
# Country not found
#  Found this hamilton
# Country not found
#  Found this castro
# Country not found
#  Found this egvekinot
# Country not found
#  Found this fairbanks
# Country not found
#  Found this lorengau
# Country not found
#  Found this marcona
# Country not found
#  Found this evensk
# Country not found
#  Found this cherskiy
# Country not found
#  Found this sacramento
# Country not found
#  Found this fallon
# Country not found
#  Found this naze
# Country not found
#  Found this tiksi
# Country not found
#  Found this puerto leguizamo
# Country not found
#  Found this bethel
# Country not found
#  Found this mataura
# Country not found
#  Found this rudbar
# Country not found
#  Found this marsa matruh
# Country not found
#  Found this xiongshi
# Country not found
#  Found this bairiki
# Country not found
#  Found this northam
# Country not found
#  Found this flinders
# Country not found
#  Found this new norfolk
# Country not found
#  Found this cape town
# Country not found
#  Found this vestmannaeyjar
# Country not found
#  Found this kirakira
# Country not found
#  Found this biak
# Country not found
#  Found this robore
# Country not found
#  Found this upernavik
# Country not found
#  Found this faanui
# Country not found
#  Found this iqaluit
# Country not found
#  Found this airai
# Country not found
#  Found this port shepstone
# Country not found
#  Found this axim
# Country not found
#  Found this kungurtug
# Country not found
#  Found this mayo
# Country not found
#  Found this kutulik
# Country not found
#  Found this ankazoabo
# Country not found
#  Found this kachug
# Country not found
#  Found this ahuimanu
# Country not found
#  Found this arraial do cabo
# Country not found
#  Found this capoterra
# Country not found
#  Found this dikson
# Country not found
#  Found this athabasca
# Country not found
#  Found this georgetown
# Country not found
#  Found this rovaniemi
# Country not found
#  Found this acapulco
# Country not found
#  Found this saldanha
# Country not found
#  Found this yichun
# Country not found
#  Found this saskylakh
# Country not found
#  Found this pindi gheb
# Country not found
#  Found this chikoy
# Country not found
#  Found this russell
# Country not found
#  Found this lolua
# Country not found
#  Found this mahebourg
# Country not found
#  Found this carnarvon
# Country not found
#  Found this zhoukou
# Country not found
#  Found this lavrentiya
# Country not found
#  Found this east london
# Country not found
#  Found this bilibino
# Country not found
#  Found this pagman
# Country not found
#  Found this clyde river
# Country not found
#  Found this luangwa
# Country not found
#  Found this half moon bay
# Country not found
#  Found this lima
# Country not found
#  Found this belushya guba
# Country not found
#  Found this vicksburg
# Country not found
#  Found this tuktoyaktuk
# Country not found
#  Found this chuy
# Country not found
#  Found this cabedelo
# Country not found
#  Found this novopokrovka
# Country not found
#  Found this ilulissat
# Country not found
#  Found this intipuca
# Country not found
#  Found this roald
# Country not found
#  Found this vaitape
# Country not found
#  Found this pecos
# Country not found
#  Found this geresk
# Country not found
#  Found this tuatapere
# Country not found
#  Found this umzimvubu
# Country not found
#  Found this winchester
# Country not found
#  Found this nikolskoye
# Country not found
#  Found this lianyuan
# Country not found
#  Found this grand river south east
# Country not found
#  Found this grindavik
# Country not found
#  Found this llanes
# Country not found
#  Found this nome
# Country not found
#  Found this klaksvik
# Country not found
#  Found this qaanaaq
# Country not found
#  Found this vaini
# Country not found
#  Found this komsomolskiy
# Country not found
#  Found this pokhara
# Country not found
#  Found this aksu
# Country not found
#  Found this coxim
# Country not found
#  Found this barentsburg
# Country not found
#  Found this booue
# Country not found
#  Found this puerto ayora
# Country not found
#  Found this honningsvag
# Country not found
#  Found this fort nelson
# Country not found
#  Found this kautokeino
# Country not found
#  Found this de panne
# Country not found
#  Found this wajima
# Country not found
#  Found this balimo
# Country not found
#  Found this ulaangom
# Country not found
#  Found this mimongo
# Country not found
#  Found this nampula
# Country not found
#  Found this meulaboh
# Country not found
#  Found this brigantine
# Country not found
#  Found this hastings
# Country not found
#  Found this namibe
# Country not found
#  Found this longyearbyen
# Country not found
#  Found this muros
# Country not found
#  Found this bengkulu
# Country not found
#  Found this isangel
# Country not found
#  Found this bubaque
# Country not found
#  Found this berlevag
# Country not found
#  Found this seredka
# Country not found
#  Found this necochea
# Country not found
#  Found this tirlyanskiy
# Country not found
#  Found this taolanaro
# Country not found
#  Found this cranbrook
# Country not found
#  Found this ous
# Country not found
#  Found this sentyabrskiy
# Country not found
#  Found this sao joao da barra
# Country not found
#  Found this paamiut
# Country not found
#  Found this ostrovnoy
# Country not found
#  Found this almaznyy
# Country not found
#  Found this fare
# Country not found
#  Found this shakawe
# Country not found
#  Found this superior
# Country not found
#  Found this charters towers
# Country not found
#  Found this homer
# Country not found
#  Found this svetlogorsk
# Country not found
#  Found this labrea
# Country not found
#  Found this savelugu
# Country not found
#  Found this paracuru
# Country not found
#  Found this grand gaube
# Country not found
#  Found this luau
# Country not found
#  Found this kasama
# Country not found
#  Found this souillac
# Country not found
#  Found this victoria
# Country not found
#  Found this atar
# Country not found
#  Found this bridgewater
# Country not found
#  Found this port elizabeth
# Country not found
#  Found this khonsa
# Country not found
#  Found this kodiak
# Country not found
#  Found this mys shmidta
# Country not found
#  Found this almirante tamandare
# Country not found
#  Found this liverpool
# Country not found
#  Found this coquimbo
# Country not found
#  Found this villarrica
# Country not found
#  Found this asau
# Country not found
#  Found this samusu
# Country not found
#  Found this oranjestad
# Country not found
#  Found this hay river
# Country not found
#  Found this bambous virieux
# Country not found
#  Found this port hardy
# Country not found
#  Found this port moresby
# Country not found
#  Found this poum
# Country not found
#  Found this pangnirtung
# Country not found
#  Found this lhuntshi
# Country not found
#  Found this tarabuco
# Country not found
#  Found this butaritari
# Country not found
#  Found this umm lajj
# Country not found
#  Found this vyazemskiy
# Country not found
#  Found this tilichiki
# Country not found
#  Found this te anau
# Country not found
#  Found this ucluelet
# Country not found
#  Found this nizhneyansk
# Country not found
#  Found this vrede
# Country not found
#  Found this youghal
# Country not found
#  Found this ballina
# Country not found
#  Found this camopi
# Country not found
#  Found this turukhansk
# Country not found
#  Found this oranjemund
# Country not found
#  Found this ulladulla
# Country not found
#  Found this chokurdakh
# Country not found
#  Found this san patricio
# Country not found
#  Found this henderson
# Country not found
#  Found this erenhot
# Country not found
#  Found this port blair
# Country not found
#  Found this omboue
# Country not found
#  Found this los llanos de aridane
# Country not found
#  Found this hasaki
# Country not found
#  Found this hovd
# Country not found
#  Found this yinchuan
# Country not found
#  Found this farmington
# Country not found
#  Found this narsaq
# Country not found
#  Found this flin flon
# Country not found
#  Found this eyl
# Country not found
#  Found this gherghesti
# Country not found
#  Found this tecoanapa
# Country not found
#  Found this mildura
# Country not found
#  Found this yaan
# Country not found
#  Found this henties bay
# Country not found
#  Found this dingle
# Country not found
#  Found this westport
# Country not found
#  Found this srednekolymsk
# Country not found
#  Found this seoul
# Country not found
#  Found this lufilufi
# Country not found
#  Found this catuday
# Country not found
#  Found this sarkikaraagac
# Country not found
#  Found this marienburg
# Country not found
#  Found this pevek
# Country not found
#  Found this kununurra
# Country not found
#  Found this balkhash
# Country not found
#  Found this barcelos
# Country not found
#  Found this namatanai
# Country not found
#  Found this ituni
# Country not found
#  Found this taltal
# Country not found
#  Found this ponta do sol
# Country not found
#  Found this norman wells
# Country not found
#  Found this salalah
# Country not found
#  Found this yulara
# Country not found
#  Found this dolbeau
# Country not found
#  Found this opportunity
# Country not found
#  Found this port lincoln
# Country not found
#  Found this lompoc
# Country not found
#  Found this orgun
# Country not found
#  Found this pekan
# Country not found
#  Found this la ronge
# Country not found
#  Found this progreso
# Country not found
#  Found this tawkar
# Country not found
#  Found this qandala
# Country not found
#  Found this traipu
# Country not found
#  Found this salto
# Country not found
#  Found this sioux lookout
# Country not found
#  Found this krasnoarmeyskoye
# Country not found
#  Found this suifenhe
# Country not found
#  Found this gamboula
# Country not found
#  Found this wewak
# Country not found
#  Found this tsihombe
# Country not found
#  Found this caravelas
# Country not found
#  Found this razole
# Country not found
#  Found this maceio
# Country not found
#  Found this west wendover
# Country not found
#  Found this qasigiannguit
# Country not found
#  Found this padang
# Country not found
#  Found this vila velha
# Country not found
#  Found this trapani
# Country not found
#  Found this berbera
# Country not found
#  Found this micheweni
# Country not found
#  Found this ahipara
# Country not found
#  Found this tessalit
# Country not found
#  Found this comodoro rivadavia
# Country not found
#  Found this svetlaya
# Country not found
#  Found this okha
# Country not found
#  Found this jasper
# Country not found
#  Found this nanyuki
# Country not found
#  Found this abalak
# Country not found
#  Found this ampanihy
# Country not found
#  Found this taoudenni
# Country not found
#  Found this makakilo city
# Country not found
#  Found this basna
# Country not found
#  Found this bato
# Country not found
#  Found this bay roberts
# Country not found
#  Found this sorland
# Country not found
#  Found this buqayq
# Country not found
#  Found this lagunas
# Country not found
#  Found this cabo san lucas
# Country not found
#  Found this saleaula
# Country not found
#  Found this sahrak
# Country not found
#  Found this road town
# Country not found
#  Found this marystown
# Country not found
#  Found this lagoa
# Country not found
#  Found this paita
# Country not found
#  Found this mackay
# Country not found
#  Found this broken hill
# Country not found
#  Found this cidreira
# Country not found
#  Found this constitucion
# Country not found
#  Found this kavaratti
# Country not found
#  Found this ayagoz
# Country not found
#  Found this ancud
# Country not found
#  Found this geraldton
# Country not found
#  Found this arman
# Country not found
#  Found this jiaojiang
# Country not found
#  Found this khania
# Country not found
#  Found this the valley
# Country not found
#  Found this santa maria
# Country not found
#  Found this arona
# Country not found
#  Found this pokanayevka
# Country not found
#  Found this bathsheba
# Country not found
#  Found this dubai
# Country not found
#  Found this zavallya
# Country not found
#  Found this plettenberg bay
# Country not found
#  Found this bunol
# Country not found
#  Found this mayenne
# Country not found
#  Found this ganzhou
# Country not found
#  Found this hofn
# Country not found
#  Found this rungata
# Country not found
#  Found this talnakh
# Country not found
#  Found this corrientes
# Country not found
#  Found this lasa
# Country not found
#  Found this kieta
# Country not found
#  Found this sarkand
# Country not found
#  Found this deputatskiy
# Country not found
#  Found this orlik
# Country not found
#  Found this emirdag
# Country not found
#  Found this vardo
# Country not found
#  Found this minna
# Country not found
#  Found this mehamn
# Country not found
#  Found this omsukchan
# Country not found
#  Found this zlatoustovsk
# Country not found
#  Found this nuevo progreso
# Country not found
#  Found this saint combs
# Country not found
#  Found this amahai
# Country not found
#  Found this codrington
# Country not found
#  Found this tunduru
# Country not found
#  Found this san andres
# Country not found
#  Found this sibiti
# Country not found
#  Found this sao gabriel da cachoeira
# Country not found
#  Found this finschhafen
# Country not found
#  Found this zyryanka
# Country not found
#  Found this rongcheng
# Country not found
#  Found this ilave
# Country not found
#  Found this karaul
# Country not found
#  Found this provideniya
# Country not found
#  Found this louisbourg
# Country not found
#  Found this atasu
# Country not found
#  Found this severo-kurilsk
# Country not found
#  Found this bolshegrivskoye
# Country not found
#  Found this soavinandriana
# Country not found
#  Found this teacapan
# Country not found
#  Found this calvinia
# Country not found
#  Found this vidim
# Country not found
#  Found this auriflama
# Country not found
#  Found this acaponeta
# Country not found
#  Found this kaeo
# Country not found
#  Found this tulum
# Country not found
#  Found this paso de los toros
# Country not found
#  Found this touros
# Country not found
#  Found this beira
# Country not found
#  Found this korla
# Country not found
#  Found this morehead
# Country not found
#  Found this puerto escondido
# Country not found
#  Found this vila do maio
# Country not found
#  Found this yola
# Country not found
#  Found this truth or consequences
# Country not found
#  Found this tiffin
# Country not found
#  Found this kuusamo
# Country not found
#  Found this karatuzskoye
# Country not found
#  Found this grand centre
# Country not found
#  Found this micomeseng
# Country not found
#  Found this ust-ilimsk
# Country not found
#  Found this zhigansk
# Country not found
#  Found this kavieng
# Country not found
#  Found this tatvan
# Country not found
#  Found this umm kaddadah
# Country not found
#  Found this grand-lahou
# Country not found
#  Found this peniche
# Country not found
#  Found this gusau
# Country not found
#  Found this haines junction
# Country not found
#  Found this zakharovo
# Country not found
#  Found this paipa
# Country not found
#  Found this carballo
# Country not found
#  Found this madimba
# Country not found
#  Found this manbij
# Country not found
#  Found this barahona
# Country not found
#  Found this isiro
# Country not found
#  Found this sogdiondon
# Country not found
#  Found this aykhal
# Country not found
#  Found this buala
# Country not found
#  Found this dvinskoy
# Country not found
#  Found this teguise
# Country not found
#  Found this zolotinka
# Country not found
#  Found this hami
# Country not found
#  Found this kodinsk
# Country not found
#  Found this mount gambier
# Country not found
#  Found this cahul
# Country not found
#  Found this marzuq
# Country not found
#  Found this trelew
# Country not found
#  Found this nishihara
# Country not found
#  Found this jalu
# Country not found
#  Found this leshukonskoye
# Country not found
#  Found this port stanley
# Country not found
#  Found this sicuani
# Country not found
#  Found this sechura
# Country not found
#  Found this sarab
# Country not found
#  Found this husavik
# Country not found
#  Found this anloga
# Country not found
#  Found this sambava
# Country not found
#  Found this attawapiskat
# Country not found
#  Found this vaitupu
# Country not found
#  Found this nyurba
# Country not found
#  Found this vila
# Country not found
#  Found this ak-dovurak
# Country not found
#  Found this hualmay
# Country not found
#  Found this kamiiso
# Country not found
#  Found this billings
# Country not found
#  Found this ixcatepec
# Country not found
#  Found this rocha
# Country not found
#  Found this nador
# Country not found
#  Found this brae
# Country not found
#  Found this vernon
# Country not found
#  Found this ondorhaan
# Country not found
#  Found this xam nua
# Country not found
#  Found this san juan
# Country not found
#  Found this terney
# Country not found
#  Found this bilma
# Country not found
#  Found this ust-abakan
# Country not found
#  Found this mattru
# Country not found
#  Found this kristiansund
# Country not found
#  Found this banjarmasin
# Country not found
#  Found this buraydah
# Country not found
#  Found this vaasa
# Country not found
#  Found this fortuna
# Country not found
#  Found this campohermoso
# Country not found
#  Found this leningradskiy
# Country not found
#  Found this elko
# Country not found
#  Found this takoradi
# Country not found
#  Found this kattivakkam
# Country not found
#  Found this lakatoro
# Country not found
#  Found this daru
# Country not found
#  Found this lichinga
# Country not found
#  Found this luderitz
# Country not found
#  Found this villa rica
# Country not found
#  Found this mezen
# Country not found
#  Found this ornskoldsvik
# Country not found
#  Found this pemberton
# Country not found
#  Found this chattanooga
# Country not found
#  Found this hirara
# Country not found
#  Found this gamba
# Country not found
#  Found this funadhoo
# Country not found
#  Found this rab
# Country not found
#  Found this yokadouma
# Country not found
#  Found this yuzhno-yeniseyskiy
# Country not found
#  Found this suntar
# Country not found
#  Found this camocim
# Country not found
#  Found this amapa
# Country not found
#  Found this shimoda
# Country not found
#  Found this bossangoa
# Country not found
#  Found this natal
# Country not found
#  Found this karangasem
# Country not found
#  Found this pangody
# Country not found
#  Found this burns lake
# Country not found
#  Found this port macquarie
# Country not found
#  Found this mbanza-ngungu
# Country not found
#  Found this bismarck
# Country not found
#  Found this saint-georges
# Country not found
#  Found this sheridan
# Country not found
#  Found this arlit
# Country not found
#  Found this launceston
# Country not found
#  Found this aklavik
# Country not found
#  Found this olinda
# Country not found
#  Found this xichang
# Country not found
#  Found this novo aripuana
# Country not found
#  Found this salinopolis
# Country not found
#  Found this bavly
# Country not found
#  Found this quatre cocos
# Country not found
#  Found this bolungarvik
# Country not found
#  Found this lundazi
# Country not found
#  Found this shenkursk
# Country not found
#  Found this fershampenuaz
# Country not found
#  Found this juneau
# Country not found
#  Found this lahat
# Country not found
#  Found this baykit
# Country not found
#  Found this chemax
# Country not found
#  Found this bartlesville
# Country not found
#  Found this khandyga
# Country not found
#  Found this briceni
# Country not found
#  Found this port said
# Country not found
#  Found this oriximina
# Country not found
#  Found this tubruq
# Country not found
#  Found this karratha
# Country not found
#  Found this parksville
# Country not found
#  Found this tsaratanana
# Country not found
#  Found this santa rosa
# Country not found
#  Found this sungaipenuh
# Country not found
#  Found this olafsvik
# Country not found
#  Found this dunedin
# Country not found
#  Found this boralday
# Country not found
#  Found this touba
# Country not found
#  Found this shache
# Country not found
#  Found this mapiripan
# Country not found
#  Found this banjar
# Country not found
#  Found this pervomayskiy
# Country not found
#  Found this waipawa
# Country not found
#  Found this escarcega
# Country not found
#  Found this lucapa
# Country not found
#  Found this ponta delgada
# Country not found
#  Found this ramhormoz
# Country not found
#  Found this ishigaki
# Country not found
#  Found this qesarya
# Country not found
#  Found this aktau
# Country not found
#  Found this moron
# Country not found
#  Found this san policarpo
# Country not found
#  Found this mukhen
# Country not found
#  Found this ambon
# Country not found
#  Found this severnoye
# Country not found
#  Found this tijara
# Country not found
#  Found this udachnyy
# Country not found
#  Found this walvis bay
# Country not found
#  Found this bonavista
# Country not found
#  Found this bulgan
# Country not found
#  Found this aswan
# Country not found
#  Found this krasnoselkup
# Country not found
#  Found this umm durman
# Country not found
#  Found this nuevitas
# Country not found
#  Found this redmond
# Country not found
#  Found this sur
# Country not found
#  Found this nesna
# Country not found
#  Found this nouadhibou
# Country not found
#  Found this mandera
# Country not found
#  Found this medea
# Country not found
#  Found this sobolevo
# Country not found
#  Found this panguna
# Country not found
#  Found this palabuhanratu
# Country not found
#  Found this verkhnyaya inta
# Country not found
#  Found this dubenskiy
# Country not found
#  Found this maltahohe
# Country not found
#  Found this sola
# Country not found
#  Found this congleton
# Country not found
#  Found this kosh-agach
# Country not found
#  Found this kuliyapitiya
# Country not found
#  Found this hambantota
# Country not found
#  Found this spas-demensk
# Country not found
#  Found this nampa
# Country not found
#  Found this asosa
# Country not found
#  Found this morgan city
# Country not found
#  Found this north bend
# Country not found
#  Found this kuala terengganu
# Country not found
#  Found this imeni zhelyabova
# Country not found
#  Found this batagay-alyta
# Country not found
#  Found this silver city
# Country not found
#  Found this artyk
# Country not found
#  Found this olovyannaya
# Country not found
#  Found this esperance
# Country not found
#  Found this orange cove
# Country not found
#  Found this wawa
# Country not found
#  Found this botou
# Country not found
#  Found this satitoa
# Country not found
#  Found this cascais
# Country not found
#  Found this greenwood
# Country not found
#  Found this adrar
# Country not found
#  Found this alice springs
# Country not found
#  Found this shelburne
# Country not found
#  Found this nadym
# Country not found
#  Found this tonekabon
# Country not found
#  Found this sligo
# Country not found
#  Found this campbell river
# Country not found
#  Found this gushikawa
# Country not found
#  Found this rio grande
# Country not found
#  Found this sawakin
# Country not found
#  Found this chitrakonda
# Country not found
#  Found this karamea
# Country not found
#  Found this boda
# Country not found
#  Found this kurilsk
# Country not found
#  Found this sibolga
# Country not found
#  Found this nieuw nickerie
# Country not found
#  Found this aquiraz
# Country not found
#  Found this solnechnyy
# Country not found
#  Found this nalut
# Country not found
#  Found this hearst
# Country not found
#  Found this likasi
# Country not found
#  Found this kunyang
# Country not found
#  Found this monterey
# Country not found
#  Found this mayya
# Country not found
#  Found this phan rang
# Country not found
#  Found this trinidad
# Country not found
#  Found this trujillo
# Country not found
#  Found this bundaberg
# Country not found
#  Found this tura
# Country not found
#  Found this sao felix do xingu
# Country not found
#  Found this batken
# Country not found
#  Found this san cristobal
# Country not found
#  Found this payo
# Country not found
#  Found this naumburg
# Country not found
#  Found this miyako
# Country not found

# %%
weatherdf =pd.DataFrame(city_data)
weatherdf["Temperature"] = round(1.8 * weatherdf['Temperature'] + 32,2)
weatherdf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temperature'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c1e19bd81412> in <module>
#       1 weatherdf =pd.DataFrame(city_data)
# ----> 2 weatherdf["Temperature"] = round(1.8 * weatherdf['Temperature'] + 32,2)
#       3 weatherdf
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Temperature'

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#no cities over 100% humidity
overhum = dataframe[dataframe["Humidity"]>100]
overhum

# %%
#  Get the indices of cities that have humidity over 100%.
#N/A

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#N/A

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#scatterplot Temp vs Latitude

plt.scatter(weatherdf["Latitude"], weatherdf["Temperature"], facecolors = 'blue', marker = 'o')

plt.title("City Latitude vs Temperature (F)")
plt.xlabel("City Latitude")
plt.ylabel("City Temperature (F)")

plt.show()
#Observation: The closer the city is to the equator, the higher the temperature. 
#Also, the northern hemisphere cities are getting colder than the southern hemispherer cities.
#Factors to consider:  Winter vs Summer in the hemispheres.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-ac21ade1e66a> in <module>
#       1 #scatterplot Temp vs Latitude
#       2
# ----> 3 plt.scatter(weatherdf["Latitude"], weatherdf["Temperature"], facecolors = 'blue', marker = 'o')
#       4
#       5 plt.title("City Latitude vs Temperature (F)")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Latitude'

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weatherdf["Latitude"], weatherdf["Humidity"], facecolors = 'blue', marker = 'o')

plt.title("Latitude vs Humidity %")
plt.xlabel("City Latitude")
plt.ylabel("City Humidity %")

plt.show()
#Observation: The cities closest to the equator does not necessarily mean the humidity percentage is higher.  
#If fact, some cities closer to the equator are less humidity right now than other cities. 
#Factors to consider:  Winter vs Summer in the hemispheres.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weatherdf["Latitude"], weatherdf["Cloudiness"], facecolors = 'blue', marker = 'o')

plt.title("Latitude vs Cloudiness %")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness %")

plt.show()
#Observations: Cities tend to have more 0% cloudiness or 100% than anything in between no matter the city's latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weatherdf["Latitude"], weatherdf["Windspeed"], facecolors = 'blue', marker = 'o')

plt.title("Latitude vs Wind Speed (mph)")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (mph)")

plt.show()
#Observations: The city's latitude does not have a high correlation with the wind speed in that city. Most city's wind blows at about 5mph or lower each day.

# %% [markdown]
# ## Linear Regression

# %%
#dataframe for just North Hemisphere
northtemp = dataframe[dataframe["Latitude"]>0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#define the axis
x_values = northtemp['Latitude']
y_values = northtemp['Temperature']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

#define regression values
regress_values = x_values * slope + intercept
#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
stats.linregress(x_values, y_values)

# %%
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.title("North Hemisphere: City Latitude vs Temperature (F)")
plt.xlabel(' City Latitude')
plt.ylabel('City Temperature (F)')
plt.annotate(line_eq,(20,15),fontsize=16,color="blue")

# Print r value by squaring it
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()

# %%
plt.scatter(x_values, y_values, facecolors = 'blue', marker = 'o')
plt.title("North Hemisphere: City Latitude vs Temperature (F)")
plt.xlabel("City Latitude")
plt.ylabel("City Temperature (F)")

plt.show()
#Observations: The further away from the equator, the clolder the temperature. (drops in a linear way)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#define souhern hemisphere dataframe
southtemp = dataframe[dataframe["Latitude"]<0]
southtemp

# %%
#define the axis
x_values = southtemp['Latitude']
y_values = southtemp['Temperature']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

#define regression values
regress_values = x_values * slope + intercept
#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
stats.linregress(x_values, y_values)

# %%
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.title("North Hemisphere: City Latitude vs Temperature (F)")
plt.xlabel(' City Latitude')
plt.ylabel('City Temperature (F)')
plt.annotate(line_eq,(20,15),fontsize=16,color="blue")

# Print r value by squaring it
print(f"The r value is: {rvalue**2}")

# Show plot
plt.show()

# %%
#scatterplot southern hemisphere latitude vs temperature
plt.scatter(southtemp["Latitude"], southtemp["Temperature"], facecolors = 'blue', marker = 'o')
plt.title("South Hemisphere: City Latitude vs Temperature (F)")
plt.xlabel("City Latitude")
plt.ylabel("City Temperature (F)")

plt.show()
#Observations: The cities in the souther hemisphere show an decrease in temperature as they get further from the equator.
#The correlation isn't as strong as the northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(northtemp["Latitude"], northtemp["Humidity"], facecolors = 'blue', marker = 'o')

plt.title("North Hemisphere: City Latitude vs Humdity (%)")
plt.xlabel("City Latitude")
plt.ylabel("City Humdity (%)")

plt.show()
#Observations: The further away from the equator, the clolder the temperature. (drops in a linear way)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(southtemp["Latitude"], southtemp["Humidity"], facecolors = 'blue', marker = 'o')

plt.title("South Hemisphere: City Latitude vs Humidity (%)")
plt.xlabel("City Latitude")
plt.ylabel("City Humidity (%)")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(northtemp["Latitude"], northtemp["Cloudiness"], facecolors = 'blue', marker = 'o')

plt.title("North Hemisphere: City Latitude vs Cloudiness %")
plt.xlabel("City Latitude")
plt.ylabel("City Cloudiness %")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(southtemp["Latitude"], southtemp["Humidity"], facecolors = 'blue', marker = 'o')

plt.title("South Hemisphere: City Latitude vs Cloudiness %")
plt.xlabel("City Latitude")
plt.ylabel("City Cloudiness %")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(northtemp["Latitude"], northtemp["Windspeed"], facecolors = 'blue', marker = 'o')

plt.title("North Hemisphere: City Latitude vs Windspeed (mph)")
plt.xlabel("City Latitude")
plt.ylabel("City Windspeed (mph)")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(southtemp["Latitude"], southtemp["Windspeed"], facecolors = 'blue', marker = 'o')

plt.title("South Hemisphere: City Latitude vs Windspeed (mph)")
plt.xlabel("City Latitude")
plt.ylabel("City Windspeed (mph)")

plt.show()
